# %% [markdown]
# # EVA-02 Training — Colab (T4)
#
# Thin runner notebook. All logic lives in `src/`; this notebook just installs
# dependencies, mounts Drive, and calls the training/inference entrypoints.
# Edit hyperparameters in `configs/eva02_base.yaml`, not here.

# %%
# !pip install timm albumentations scikit-learn pandas tqdm pyyaml -q

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone the repo (first run) or pull latest (subsequent runs)
import os
REPO_URL = "https://github.com/<your-username>/etsy-ai-detection.git"
REPO_DIR = "/content/etsy-ai-detection"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # !cd {REPO_DIR} && git pull

# %cd {REPO_DIR}

# %%
# Unzip the challenge images (run once per Colab session)
# !python -m src.prepare_data --config configs/eva02_base.yaml

# %%
# Train — logs, checkpoint, metrics, confusion matrix all handled inside src/train.py
# !python -m src.train --config configs/eva02_base.yaml

# %%
# Run inference on the test set using the best checkpoint
# !python -m src.infer --config configs/eva02_base.yaml --checkpoint /content/drive/MyDrive/best_eva02_checkpoint.pth
